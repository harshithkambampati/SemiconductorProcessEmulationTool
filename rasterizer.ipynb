# %% [markdown]
# <a href="https://colab.research.google.com/github/harshithkambampati/SemiconductorProcessEmulationTool/blob/main/rasterizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# 1. Configure Git (run this once)
# Replace with your GitHub email and username
# !git config --global user.email "your_email@example.com"
# !git config --global user.name "Your Name"

# 2. Clone your repository
# Replace with your repository URL. For private repos, use a Personal Access Token (PAT).
# Example for public repo: !git clone https://github.com/your_username/your_repo_name.git
# Example for private repo with PAT:
# You'll be prompted for your username and password (use PAT as password).
# Or embed PAT in URL (less secure but works for automation):
# !git clone https://your_username:your_personal_access_token@github.com/your_username/your_repo_name.git

# For demonstration, let's assume a public repo for cloning or create a dummy folder
# IMPORTANT: Create your actual repository on GitHub first if you haven't.
repo_url = "https://github.com/your_username/your_repo_name.git" # <-- REPLACE THIS
repo_name = "your_repo_name" # <-- REPLACE THIS with the actual repo folder name

# Check if the directory already exists to avoid cloning multiple times
if not os.path.exists(repo_name):
    print(f"Cloning {repo_url}...")
    # !git clone {repo_url}
    print("Repository cloned.")
else:
    print(f"Repository '{repo_name}' already exists. Skipping clone.")

# 3. Change directory into your repository
# This is crucial so Git commands apply to your repo
# %cd {repo_name}

# 4. (Optional) Create or copy your Colab notebook into the repository folder
# If you are saving the current Colab notebook, you might download it and then upload here
# Or if you are working on a new file, create it directly.
# For example, to create a dummy file:
# with open('my_colab_notebook.ipynb', 'w') as f:
#     f.write('This is a dummy notebook content.')

# If your Colab notebook is saved in the current Colab environment and you want to push it:
# You would typically download it from File -> Download -> Download .ipynb and then upload/move it here.
# Or, if you want to push the *current* notebook you are working on, it's often easier
# to use File -> Save a copy to GitHub, which is a Colab UI feature.

# To push a file that's already in the Colab environment (e.g., if you opened it from GitHub)
# or if you manually saved/created a file:

# 5. Add your notebook file(s) to the staging area
# Replace 'your_notebook_name.ipynb' with the actual name of your notebook or use '.' for all changes
# !git add .

# 6. Commit your changes
# !git commit -m "Add Colab notebook file"

# 7. Push your changes to GitHub
# 'origin' refers to the remote repository you cloned from.
# 'main' or 'master' is typically the default branch name.
# You might be prompted for your username and password/PAT if not using PAT in URL.
# !git push origin main # or !git push origin master, depending on your branch name

print("Changes pushed to GitHub!")

# To verify, you can also run:
# !git status
# !git log --oneline
